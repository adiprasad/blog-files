# %% [markdown]
# # Creating an image dataset using character images from Stanford OCR and Tokens from Gutenberg

# %% [markdown]
# ## Imports

# %%
import numpy as np
from sets import Set 
from collections import defaultdict
import pickle
import nltk
import re
import os
import pickle
from string import lower
from sklearn.model_selection import train_test_split
from collections import Counter
import matplotlib.pyplot as plt
from string import lower

# %% [markdown]
# ## Creating a character image variants dictionary

# %%
data_file = open('letter.data', 'r')
char_pixel_dict = defaultdict(Set)	# key : character, value : set of pixel array variants for that character


for line in data_file:
	data_arr = line.split()
	char = data_arr[1]

	char_label = ord(char) - 97

	char_features = map(lambda x : int(x), data_arr[6:])

	char_set = char_pixel_dict.get(char, Set())

	char_feature_tup = tuple(char_features)

	char_set.add(char_feature_tup)

	char_pixel_dict[char] = char_set

    

for key, val in char_pixel_dict.items():
	print "Character : " + str(key)
	print "Number of variants: " + str(len(val))


with open("./letter_variants.npy", "w") as f:
	pickle.dump(char_pixel_dict, f)
# Out:
# Character : a
# Number of variants: 4021
# Character : c
# Number of variants: 2072
# Character : b
# Number of variants: 1282
# Character : e
# Number of variants: 4945
# Character : d
# Number of variants: 1441
# Character : g
# Number of variants: 2471
# Character : f
# Number of variants: 921
# Character : i
# Number of variants: 4027
# Character : h
# Number of variants: 861
# Character : k
# Number of variants: 909
# Character : j
# Number of variants: 189
# Character : m
# Number of variants: 1587
# Character : l
# Number of variants: 1696
# Character : o
# Number of variants: 3854
# Character : n
# Number of variants: 4988
# Character : q
# Number of variants: 341
# Character : p
# Number of variants: 1377
# Character : s
# Number of variants: 1394
# Character : r
# Number of variants: 2634
# Character : u
# Number of variants: 2538
# Character : t
# Number of variants: 2126
# Character : w
# Number of variants: 520
# Character : v
# Number of variants: 661
# Character : y
# Number of variants: 1221
# Character : x
# Number of variants: 413
# Character : z
# Number of variants: 1091

# %% [markdown]
# ## Script to create images and labels for tokens extracted from the book Moby Dick

# %%
def get_dir(dir_name):
	dir_path = os.path.join(os.getcwd(), dir_name)
	
	if (not os.path.exists(dir_path)):
		os.makedirs(dir_path)

	return dir_path

def init_gutenberg():
	nltk.download('gutenberg')


def get_book_tokens_gt_len(book_name, length):
	book_tokens = nltk.corpus.gutenberg.words(book_name)
	book_token_set = Set(book_tokens)
	book_token_list = map(lambda x : x.strip(), book_token_set)
	book_words = filter(lambda x : re.match(r'^[a-zA-Z]+$', x), book_token_list)
	book_words_gt_eq_len = filter(lambda x : len(x) >= length, book_words)

	book_words_gt_eq_len = map(lambda x : lower(x), book_words_gt_eq_len)

	return np.array(book_words_gt_eq_len)

def _get_file_name(img_num, file_type = "img"):
	if (file_type == "img"):
		file_name = "img_" + str(img_num) + ".png"
	else:
		file_name = "img_" + str(img_num) + ".txt"

	return file_name

def _save_img_in_folder(dir_path, img_num, word_arr):
	file_name = _get_file_name(img_num)

	file_path = os.path.join(dir_path, file_name)

	plt.imsave(file_path, word_arr)


def _draw_and_save_word_in_dir(img_num, img_arr, dir_path):
	img_arr = img_arr.reshape(img_arr.shape[0], 16,- 1)

	word_arr = img_arr[0]

	for i in range(1, len(img_arr)):
		word_arr = np.hstack((word_arr, np.zeros((16,2), dtype = int)))
		word_arr = np.hstack((word_arr, img_arr[i]))

	word_arr*=255
	word_arr = word_arr[:,8:]		# first 8 cols are zeros, 2 col padding at start and end

	_save_img_in_folder(dir_path, img_num, word_arr)


def _write_word_arr_in_dir(img_num, img_arr, dir_path):
	file_name = _get_file_name(img_num, "txt")

	file_path = os.path.join(dir_path, file_name)

	img_arr = img_arr[1:]

	with open(file_path, "w") as f:
		for img in img_arr:
			line = " ".join([`num` for num in img]) + "\n"
			f.write(line)

def save_word_to_dir(word_arr, word_num, dir_path):
	_draw_and_save_word_in_dir(word_num, word_arr, dir_path)
	_write_word_arr_in_dir(word_num, word_arr, dir_path)


def get_char_img_len(char_to_img_arr_dict):
	list_of_a_variants = list(char_to_img_arr_dict['a'])

	return len(list_of_a_variants[0])


def get_random_variant_of_char(char_to_img_arr_dict, char):
	char_variants_list = list(char_to_img_arr_dict[char])
	num_variants = len(char_variants_list)

	#print "Char : " + char
	#rint "Number of variants : " + str(num_variants)

	random_variant_idx = np.random.choice(num_variants)

	random_variant = char_variants_list[random_variant_idx]

	return np.array(random_variant)


def save_word_imgs_to_dir(words, dir_path, char_to_img_arr_dict):
	char_feature_len = get_char_img_len(char_to_img_arr_dict)

	#print "last word " + str(words[-1])

	for word_num, word in enumerate(words):
		print "Writing " + str(word) + " to file"
		word_arr = np.zeros((1,char_feature_len), dtype = int)

		for char in word:
			variant_of_char = get_random_variant_of_char(char_to_img_arr_dict, char)
			word_arr = np.vstack((word_arr, variant_of_char))

		save_word_to_dir(word_arr, word_num, dir_path)
		#print "Write successful!"


def write_words_list_to_dir(words, file_path):
	with open(file_path, 'w') as word_file:
		for word_num, word in enumerate(words):
			word_file.write(str(word_num) + " " + word + "\n")


def filter_words_for_stratification(words_list, test_split):
	len_words_list = map(lambda x : len(x), words_list)

	min_words_req_per_len = int(np.ceil(test_split * 10))

	len_words_counter = Counter(len_words_list)

	print "Len words counter " + str(len_words_counter)

	not_allowed_lengths = [x[0] for x in len_words_counter.items() if x[1] < min_words_req_per_len]

	print "Not allowed lengths " + str(not_allowed_lengths)

	len_words_list = np.array(len_words_list)

	mask = np.zeros(len(words_list), dtype=bool)

	for n_length in not_allowed_lengths:
		n_len_mask = (len_words_list == n_length)
		mask = np.ma.mask_or(mask, n_len_mask)

	inverted_mask = np.invert(mask)

	return words_list[inverted_mask]


def create_data_set(words_list, char_to_img_arr_dict, test_split):
	words_list = filter_words_for_stratification(words_list, test_split)

	print "Number of tokens after filtering " + str(len(words_list))

	len_words_list = map(lambda x : len(x), words_list)

	words_train, words_test, _ , _ = train_test_split(words_list, len_words_list, test_size = test_split, shuffle = True, stratify = len_words_list)
	
	data_dir = get_dir('data')

	train_dir_path = get_dir('data/train_words')
	test_dir_path = get_dir('data/test_words')

	train_words_file_path = os.path.join(data_dir, 'train_words.txt')
	test_words_file_path = os.path.join(data_dir, 'test_words.txt')

	save_word_imgs_to_dir(words_train, train_dir_path, char_to_img_arr_dict)
	save_word_imgs_to_dir(words_test, test_dir_path, char_to_img_arr_dict)

	write_words_list_to_dir(words_train, train_words_file_path)
	write_words_list_to_dir(words_test, test_words_file_path)

# %% [markdown]
# ## Running the data preparation script

# %%
init_gutenberg()

mb_dick_tokens = get_book_tokens_gt_len('melville-moby_dick.txt', 3)

print "Number of extracted tokens " + str(len(mb_dick_tokens))

with open("letter_variants.npy") as f:
    char_to_img_arr_dict = pickle.load(f)

create_data_set(mb_dick_tokens, char_to_img_arr_dict, 0.2)

print "Dataset preparation successful.. Check ./data"
# Out:
# [nltk_data] Downloading package gutenberg to /Users/ady/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# Number of extracted tokens 18862
# Len words counter Counter({7: 3005, 6: 2941, 8: 2708, 5: 2393, 9: 2174, 4: 1701, 10: 1440, 11: 881, 3: 589, 12: 550, 13: 286, 14: 122, 15: 48, 16: 13, 17: 9, 18: 1, 20: 1})
# Not allowed lengths [18, 20]
# Number of tokens after filtering 18860
# Writing hostile to file
# Writing impeding to file
# Writing hence to file
# Writing doubts to file
# Writing banked to file
# Writing wine to file
# Writing courteous to file
# Writing soladoes to file
# Writing background to file
# Writing nervous to file
# Writing incommodiously to file
# Writing bristling to file
# Writing unmarred to file
# Writing maliciously to file
# Writing heartwoes to file
# Writing agent to file
# Writing keystone to file
# Writing flat to file
# Writing imaginative to file
# Writing flame to file
# Writing shaved to file
# Writing evince to file
# Writing toilet to file
# Writing emir to file
# Writing furred to file
# Writing cheever to file
# Writing fertility to file
# Writing laureate to file
# Writing pulls to file
# Writing able to file
# Writing hardy to file
# Writing words to file
# Writing temperate to file
# Writing reapers to file
# Writing duplicates to file
# Writing shops to file
# Writing damndest to file
# Writing redoubled to file
# Writing streaks to file
# Writing again to file
# Writing tiled to file
# Writing corruption to file
# Writing walks to file
# Writing effaced to file
# Writing ice to file
# Writing compare to file
# Writing crackled to file
# Writing residing to file
# Writing living to file
# Writing wary to file
# Writing jovial to file
# Writing generated to file
# Writing shrines to file
# Writing reminiscence to file
# Writing prevail to file
# Writing circumnavigation to file
# Writing juniper to file
# Writing roar to file
# Writing natures to file
# Writing sailors to file
# Writing cracking to file
# Writing heeded to file
# Writing look to file
# Writing gazer to file
# Writing goldsmith to file
# Writing scorchingly to file
# Writing tokens to file
# Writing growlingly to file
# Writing sheets to file
# Writing pedestrians to file
# Writing whitsuntide to file
# Writing extinction to file
# Writing yielded to file
# Writing naturally to file
# Writing benches to file
# Writing jobs to file
# Writing advance to file
# Writing miserable to file
# Writing wrapt to file
# Writing conceded to file
# Writing reel to file
# Writing thrilled to file
# Writing revive to file
# Writing bantering to file
# Writing oddish to file
# Writing tropic to file
# Writing betake to file
# Writing truth to file
# Writing dismissed to file
# Writing glittering to file
# Writing amputated to file
# Writing coloured to file
# Writing author to file
# Writing spending to file
# Writing impressive to file
# Writing grotesqueness to file
# Writing hanoverian to file
# Writing barbecue to file
# Writing mss to file
# Writing prefecture to file
# Writing omit to file
# Writing jig to file
# Writing throws to file
# Writing polite to file
# Writing playing to file
# Writing bosom to file
# Writing tribe to file
# Writing animating to file
# Writing veer to file
# Writing dividing to file
# Writing commodores to file
# Writing bride to file
# Writing brit to file
# Writing opine to file
# Writing brow to file
# Writing clumsiest to file
# Writing show to file
# Writing grows to file
# Writing froze to file
# Writing desert to file
# Writing honourably to file
# Writing belief to file
# Writing aliment to file
# Writing stoutest to file
# Writing surpass to file
# Writing thoughted to file
# Writing topple to file
# Writing evangelists to file
# Writing canted to file
# Writing vessels to file
# Writing foundered to file
# Writing waist to file
# Writing boobies to file
# Writing sitting to file
# Writing presentations to file
# Writing boundary to file
# Writing fewer to file
# Writing commended to file
# Writing frighted to file
# Writing cripple to file
# Writing untrodden to file
# Writing keeling to file
# Writing burglar to file
# Writing cope to file
# Writing flapped to file
# Writing decorated to file
# Writing fixed to file
# Writing sup to file
# Writing sogger to file
# Writing whosoever to file
# Writing chain to file
# Writing hermetically to file
# Writing custom to file
# Writing announces to file
# Writing admiral to file
# Writing riotous to file
# Writing withstanding to file
# Writing formerly to file
# Writing capsizings to file
# Writing steamer to file
# Writing tombed to file
# Writing prairies to file
# Writing decanter to file
# Writing nineveh to file
# Writing utterance to file
# Writing spavined to file
# Writing unpainted to file
# Writing useless to file
# Writing lone to file
# Writing slapping to file
# Writing shouts to file
# Writing locking to file
# Writing dissatisfaction to file
# Writing embalmed to file
# Writing flies to file
# Writing slightly to file
# Writing pans to file
# Writing biased to file
# Writing unnaturally to file
# Writing shipmates to file
# Writing higgledy to file
# Writing stabbing to file
# Writing uses to file
# Writing whom to file
# Writing diffused to file
# Writing fields to file
# Writing course to file
# Writing scarce to file
# Writing shove to file
# Writing stowing to file
# Writing burst to file
# Writing supreme to file
# Writing off to file
# Writing astir to file
# Writing needful to file
# Writing perfectly to file
# Writing bodies to file
# Writing immersed to file
# Writing islanders to file
# Writing mortality to file
# Writing profundities to file
# Writing russian to file
# Writing assyrian to file
# Writing felicities to file
# Writing carnation to file
# Writing whipped to file
# Writing official to file
# Writing hurricane to file
# Writing cap to file
# Writing districts to file
# Writing yours to file
# Writing capturing to file
# Writing rests to file
# Writing thrust to file
# Writing answered to file
# Writing inexperienced to file
# Writing paper to file
# Writing sentinelled to file
# Writing stilly to file
# Writing affairs to file
# Writing spiralling to file
# Writing cranial to file
# Writing income to file
# Writing plantation to file
# Writing turtle to file
# Writing snoozing to file
# Writing unfathomably to file
# Writing woraciousness to file
# Writing remembering to file
# Writing emboldened to file
# Writing observatory to file
# Writing dirty to file
# Writing uttons to file
# Writing hooroosh to file
# Writing verbally to file
# Writing tied to file
# Writing ensuing to file
# Writing ferns to file
# Writing rocks to file
# Writing chalices to file
# Writing kinds to file
# Writing landscapes to file
# Writing deaf to file
# Writing wand to file
# Writing starve to file
# Writing truthfully to file
# Writing case to file
# Writing quiescent to file
# Writing curing to file
# Writing beliefs to file
# Writing direst to file
# Writing scornful to file
# Writing blueness to file
# Writing diminished to file
# Writing hugeness to file
# Writing assure to file
# Writing proprietor to file
# Writing continent to file
# Writing substantive to file
# Writing accidentally to file
# Writing inclement to file
# Writing came to file
# Writing upholding to file
# Writing songster to file
# Writing friendly to file
# Writing milling to file
# Writing substituted to file
# Writing sammy to file
# Writing unconsumed to file
# Writing lesser to file
# Writing charley to file
# Writing inferred to file
# Writing upon to file
# Writing marvellously to file
# Writing baleine to file
# Writing lonesomely to file
# Writing abstemious to file
# Writing leap to file
# Writing harbors to file
# Writing yourself to file
# Writing due to file
# Writing gill to file
# Writing octher to file
# Writing ignorantly to file
# Writing judicious to file
# Writing inert to file
# Writing houseless to file
# Writing unrustlingly to file
# Writing navigation to file
# Writing accompanying to file
# Writing lightning to file
# Writing haunt to file
# Writing frank to file
# Writing jesty to file
# Writing imputable to file
# Writing presume to file
# Writing ladders to file
# Writing avoid to file
# Writing childish to file
# Writing communicates to file
# Writing whimsicalities to file
# Writing suffusing to file
# Writing latin to file
# Writing uncanonical to file
# Writing pallor to file
# Writing kedger to file
# Writing fires to file
# Writing reveries to file
# Writing lengthwise to file
# Writing thieves to file
# Writing accept to file
# Writing weaves to file
# Writing wakeful to file
# Writing sod to file
# Writing inn to file
# Writing clouded to file
# Writing nameless to file
# Writing managing to file
# Writing stilts to file
# Writing flitted to file
# Writing holes to file
# Writing abating to file
# Writing incredibly to file
# Writing october to file
# Writing scrawl to file
# Writing look to file
# Writing enhance to file
# Writing demonism to file
# Writing skylarking to file
# Writing madness to file
# Writing decision to file
# Writing imagine to file
# Writing greatest to file
# Writing second to file
# Writing keys to file
# Writing paved to file
# Writing unstaked to file
# Writing bracton to file
# Writing subtlest to file
# Writing assist to file
# Writing antlered to file
# Writing screen to file
# Writing alow to file
# Writing instructions to file
# Writing had to file
# Writing martial to file
# Writing unfrequented to file
# Writing overhung to file
# Writing gor to file
# Writing repartees to file
# Writing fundamentals to file
# Writing cut to file
# Writing sadder to file
# Writing comparatively to file
# Writing vitals to file
# Writing tugging to file
# Writing inferiors to file
# Writing explanation to file
# Writing unmanageably to file
# Writing firmaments to file
# Writing davenant to file
# Writing squall to file
# Writing clouds to file
# Writing jacket to file
# Writing largeness to file
# Writing rise to file
# Writing jury to file
# Writing hatch to file
# Writing ruggedest to file
# Writing salute to file
# Writing smells to file
# Writing hebrew to file
# Writing hoping to file
# Writing accidents to file
# Writing chafed to file
# Writing crumpled to file
# Writing usually to file
# Writing ponderosity to file
# Writing misgrown to file
# Writing van to file
# Writing propensity to file
# Writing inventors to file
# Writing intelligence to file
# Writing ramparts to file
# Writing colourless to file
# Writing essences to file
# Writing lesson to file
# Writing talks to file
# Writing facetiousness to file
# Writing gleig to file
# Writing coming to file
# Writing limb to file
# Writing drabbest to file
# Writing birthmark to file
# Writing smithfield to file
# Writing entrenched to file
# Writing gam to file
# Writing tombstones to file
# Writing battle to file
# Writing thereabouts to file
# Writing cavities to file
# Writing tasselled to file
# Writing sorts to file
# Writing emphatically to file
# Writing persuade to file
# Writing rude to file
# Writing till to file
# Writing sentence to file
# Writing gashed to file
# Writing explanatory to file
# Writing hauled to file
# Writing ranged to file
# Writing outspread to file
# Writing madness to file
# Writing requiring to file
# Writing pegu to file
# Writing skins to file
# Writing wastingly to file
# Writing cunning to file
# Writing heavier to file
# Writing sickness to file
# Writing summers to file
# Writing immutably to file
# Writing drawn to file
# Writing lilies to file
# Writing backed to file
# Writing laudanum to file
# Writing standard to file
# Writing bunyan to file
# Writing elsewhere to file
# Writing unbroken to file
# Writing euroclydon to file
# Writing soon to file
# Writing depressions to file
# Writing unspotted to file
# Writing ironical to file
# Writing spindle to file
# Writing creak to file
# Writing tea to file
# Writing hoist to file
# Writing bruised to file
# Writing armor to file
# Writing maddens to file
# Writing unspoken to file
# Writing cohorts to file
# Writing inventing to file
# Writing hwal to file
# Writing unhinged to file
# Writing overlook to file
# Writing acre to file
# Writing testimony to file
# Writing jerkingly to file
# Writing lashless to file
# Writing settlement to file
# Writing body to file
# Writing distracted to file
# Writing newspaper to file
# Writing overruling to file
# Writing underived to file
# Writing derived to file
# Writing metallic to file
# Writing moccasined to file
# Writing medal to file
# Writing concreted to file
# Writing engage to file
# Writing moth to file
# Writing hatches to file
# Writing reverberating to file
# Writing snoring to file
# Writing producing to file
# Writing pantry to file
# Writing prows to file
# Writing wanting to file
# Writing lord to file
# Writing continental to file
# Writing blades to file
# Writing virgin to file
# Writing blinds to file
# Writing speak to file
# Writing aboriginal to file
# Writing hampton to file
# Writing sprains to file
# Writing either to file
# Writing usual to file
# Writing kidnapping to file
# Writing lion to file
# Writing nonce to file
# Writing existence to file
# Writing motioning to file
# Writing ridge to file
# Writing holds to file
# Writing druggists to file
# Writing john to file
# Writing travels to file
# Writing inanimate to file
# Writing transform to file
# Writing atrocious to file
# Writing disappointed to file
# Writing seek to file
# Writing hesitatingly to file
# Writing north to file
# Writing impaling to file
# Writing good to file
# Writing tomahawk to file
# Writing ancient to file
# Writing whale to file
# Writing auto to file
# Writing swim to file
# Writing fife to file
# Writing applies to file
# Writing keeping to file
# Writing shriek to file
# Writing greatly to file
# Writing that to file
# Writing chancing to file
# Writing mastications to file
# Writing wearing to file
# Writing shun to file
# Writing economic to file
# Writing dubious to file
# Writing ugliest to file
# Writing horrify to file
# Writing bridals to file
# Writing glared to file
# Writing pryed to file
# Writing bright to file
# Writing indulge to file
# Writing boneless to file
# Writing tost to file
# Writing lank to file
# Writing chivalric to file
# Writing bunger to file
# Writing kiln to file
# Writing hearsed to file
# Writing deputation to file
# Writing leuwenhoeck to file
# Writing community to file
# Writing knock to file
# Writing back to file
# Writing measurer to file
# Writing nod to file
# Writing tribulations to file
# Writing inculcating to file
# Writing determination to file
# Writing mouth to file
# Writing aforesaid to file
# Writing begone to file
# Writing implicit to file
# Writing indefinite to file
# Writing naturae to file
# Writing cone to file
# Writing grandmother to file
# Writing tarred to file
# Writing tablets to file
# Writing pertinaciously to file
# Writing cleats to file
# Writing specimens to file
# Writing tightly to file
# Writing artists to file
# Writing attained to file
# Writing vicissitudes to file
# Writing pursuers to file
# Writing castle to file
# Writing muskiness to file
# Writing observant to file
# Writing mayhew to file
# Writing javelin to file
# Writing herding to file
# Writing conquering to file
# Writing signers to file
# Writing bar to file
# Writing plata to file
# Writing poke to file
# Writing dallied to file
# Writing tindering to file
# Writing stopping to file
# Writing memory to file
# Writing laplander to file
# Writing viewing to file
# Writing shading to file
# Writing flourishings to file
# Writing hobbling to file
# Writing thrice to file
# Writing thrusts to file
# Writing barriers to file
# Writing formally to file
# Writing keyed to file
# Writing seated to file
# Writing lamb to file
# Writing quakeress to file
# Writing travelled to file
# Writing forehead to file
# Writing brand to file
# Writing altar to file
# Writing discernible to file
# Writing adroit to file
# Writing says to file
# Writing swear to file
# Writing walruses to file
# Writing loneliness to file
# Writing touched to file
# Writing acted to file
# Writing leads to file
# Writing entitle to file
# Writing marvellous to file
# Writing yoke to file
# Writing third to file
# Writing buries to file
# Writing parcelling to file
# Writing not to file
# Writing vivaciously to file
# Writing judgmatically to file
# Writing uncounted to file
# Writing consume to file
# Writing cachalot to file
# Writing liv to file
# Writing confession to file
# Writing tusked to file
# Writing apparatus to file
# Writing savesoul to file
# Writing loss to file
# Writing militant to file
# Writing resides to file
# Writing insulated to file
# Writing marvels to file
# Writing shall to file
# Writing joyfully to file
# Writing squalls to file
# Writing touch to file
# Writing andrew to file
# Writing events to file
# Writing forborne to file
# Writing faintly to file
# Writing lengths to file
# Writing umbrella to file
# Writing bitin to file
# Writing seizing to file
# Writing phantoms to file
# Writing hilarious to file
# Writing revelry to file
# Writing unsleeping to file
# Writing whistle to file
# Writing shone to file
# Writing grin to file
# Writing reefed to file
# Writing transferringly to file
# Writing degree to file
# Writing sing to file
# Writing closing to file
# Writing overrun to file
# Writing operas to file
# Writing knights to file
# Writing edging to file
# Writing glossy to file
# Writing unalterable to file
# Writing until to file
# Writing peak to file
# Writing conveying to file
# Writing possessing to file
# Writing effulgent to file
# Writing breaching to file
# Writing goods to file
# Writing anyway to file
# Writing bagged to file
# Writing sect to file
# Writing gases to file
# Writing obeys to file
# Writing shilling to file
# Writing struck to file
# Writing comes to file
# Writing britain to file
# Writing trenchers to file
# Writing soggy to file
# Writing abatement to file
# Writing chace to file
# Writing hussey to file
# Writing equator to file
# Writing stoic to file
# Writing humpbacked to file
# Writing promiscuously to file
# Writing skysail to file
# Writing haul to file
# Writing swiftest to file
# Writing assured to file
# Writing strike to file
# Writing dramatic to file
# Writing steaks to file
# Writing deemed to file
# Writing pyrrho to file
# Writing tierce to file
# Writing hater to file
# Writing unabated to file
# Writing turned to file
# Writing wood to file
# Writing brimmed to file
# Writing thickens to file
# Writing whisperingly to file
# Writing cogged to file
# Writing untraceable to file
# Writing spirally to file
# Writing terrific to file
# Writing stoopingly to file
# Writing citadels to file
# Writing cask to file
# Writing colossus to file
# Writing insinuating to file
# Writing mahogany to file
# Writing harto to file
# Writing physiognomical to file
# Writing shaken to file
# Writing endearments to file
# Writing sails to file
# Writing heavy to file
# Writing sweethearts to file
# Writing strolled to file
# Writing liveliness to file
# Writing happiness to file
# Writing inhaled to file
# Writing maziness to file
# Writing inexplicable to file
# Writing dorchester to file
# Writing trades to file
# Writing folio to file
# Writing confirmation to file
# Writing steerer to file
# Writing awaiting to file
# Writing expatiate to file
# Writing some to file
# Writing nigh to file
# Writing philosopher to file
# Writing boasts to file
# Writing describe to file
# Writing revelation to file
# Writing anomalous to file
# Writing outnumber to file
# Writing infantileness to file
# Writing wafted to file
# Writing uplifted to file
# Writing cutlery to file
# Writing relation to file
# Writing eddies to file
# Writing tints to file
# Writing paunch to file
# Writing dusk to file
# Writing dreaded to file
# Writing prospects to file
# Writing foie to file
# Writing goethe to file
# Writing resorting to file
# Writing reliably to file
# Writing flexions to file
# Writing humane to file
# Writing humming to file
# Writing radiating to file
# Writing forehead to file
# Writing movable to file
# Writing jones to file
# Writing daboll to file
# Writing unmindful to file
# Writing unsafe to file
# Writing nomenclature to file
# Writing sketches to file
# Writing oils to file
# Writing breakfasting to file
# Writing western to file
# Writing dictionary to file
# Writing delivery to file
# Writing snored to file
# Writing brass to file
# Writing halloo to file
# Writing carpenter to file
# Writing unsweetly to file
# Writing sexes to file
# Writing genially to file
# Writing detect to file
# Writing counterbalance to file
# Writing pass to file
# Writing unicornism to file
# Writing orphans to file
# Writing morals to file
# Writing sounded to file
# Writing newly to file
# Writing porpoise to file
# Writing icebergs to file
# Writing compassion to file
# Writing thanks to file
# Writing trailing to file
# Writing expressed to file
# Writing fill to file
# Writing grating to file
# Writing bath to file
# Writing studs to file
# Writing blandishments to file
# Writing believing to file
# Writing anxious to file
# Writing cunningly to file
# Writing worm to file
# Writing owns to file
# Writing countersunk to file
# Writing harsh to file
# Writing girds to file
# Writing silly to file
# Writing leaner to file
# Writing remark to file
# Writing stating to file
# Writing manhood to file
# Writing suspended to file
# Writing bolted to file
# Writing cheerless to file
# Writing speech to file
# Writing hope to file
# Writing created to file
# Writing ram to file
# Writing prized to file
# Writing jewel to file
# Writing translated to file
# Writing coarse to file
# Writing island to file
# Writing mended to file
# Writing candelabra to file
# Writing insupportable to file
# Writing soliloquized to file
# Writing devices to file
# Writing promotion to file
# Writing reciprocating to file
# Writing reckon to file
# Writing watching to file
# Writing evanescence to file
# Writing mastodon to file
# Writing symptoms to file
# Writing symmetry to file
# Writing wholly to file
# Writing blew to file
# Writing elevating to file
# Writing cobs to file
# Writing reaping to file
# Writing gleamings to file
# Writing brows to file
# Writing quilted to file
# Writing sharks to file
# Writing isle to file
# Writing displaced to file
# Writing prayer to file
# Writing matched to file
# Writing hand to file
# Writing tigress to file
# Writing foamingly to file
# Writing nailing to file
# Writing sumatra to file
# Writing daniel to file
# Writing nothing to file
# Writing traps to file
# Writing tubes to file
# Writing pecked to file
# Writing verdant to file
# Writing dames to file
# Writing passiveness to file
# Writing moments to file
# Writing royalties to file
# Writing ahabs to file
# Writing breezing to file
# Writing next to file
# Writing ragamuffin to file
# Writing witch to file
# Writing mediums to file
# Writing climbs to file
# Writing corn to file
# Writing imps to file
# Writing operate to file
# Writing vindicated to file
# Writing pent to file
# Writing issuing to file
# Writing fifty to file
# Writing cuvier to file
# Writing revery to file
# Writing toothache to file
# Writing tendrils to file
# Writing cod to file
# Writing ascribable to file
# Writing breakers to file
# Writing degrees to file
# Writing decrees to file
# Writing ones to file
# Writing marvelled to file
# Writing accommodation to file
# Writing moonlight to file
# Writing hum to file
# Writing bepatched to file
# Writing having to file
# Writing unhesitatingly to file
# Writing twiske to file
# Writing contrivance to file
# Writing peaceable to file
# Writing new to file
# Writing huge to file
# Writing condemned to file
# Writing cooks to file
# Writing hay to file
# Writing pine to file
# Writing thick to file
# Writing projected to file
# Writing spanned to file
# Writing prodigies to file
# Writing underwriter to file
# Writing see to file
# Writing ajar to file
# Writing wolves to file
# Writing gases to file
# Writing yelled to file
# Writing impelled to file
# Writing intercept to file
# Writing sink to file
# Writing sonorous to file
# Writing grief to file
# Writing surviving to file
# Writing thine to file
# Writing unentered to file
# Writing plasters to file
# Writing voyages to file
# Writing artistic to file
# Writing frolic to file
# Writing allowing to file
# Writing consulted to file
# Writing lovings to file
# Writing fists to file
# Writing changing to file
# Writing paler to file
# Writing jumbled to file
# Writing became to file
# Writing paddling to file
# Writing examined to file
# Writing attract to file
# Writing entrance to file
# Writing gondibert to file
# Writing vidocq to file
# Writing carelessness to file
# Writing swoop to file
# Writing cattle to file
# Writing bloody to file
# Writing quenchless to file
# Writing jettest to file
# Writing execute to file
# Writing kelpy to file
# Writing treat to file
# Writing imperceptible to file
# Writing several to file
# Writing burst to file
# Writing noiseless to file
# Writing cordon to file
# Writing actium to file
# Writing displayed to file
# Writing sullenly to file
# Writing king to file
# Writing collision to file
# Writing emptied to file
# Writing advance to file
# Writing bloody to file
# Writing obstinacy to file
# Writing unbuckling to file
# Writing devoting to file
# Writing pelisse to file
# Writing satisfaction to file
# Writing gallery to file
# Writing notified to file
# Writing lets to file
# Writing swim to file
# Writing expressing to file
# Writing whalemen to file
# Writing ratifying to file
# Writing placing to file
# Writing westerly to file
# Writing tools to file
# Writing hudson to file
# Writing horses to file
# Writing articles to file
# Writing burke to file
# Writing string to file
# Writing flaked to file
# Writing specksioneer to file
# Writing magistrate to file
# Writing corroded to file
# Writing fleeting to file
# Writing ventricles to file
# Writing unmixed to file
# Writing mateship to file
# Writing lean to file
# Writing blood to file
# Writing cosmopolite to file
# Writing offensively to file
# Writing offence to file
# Writing journey to file
# Writing elsewhere to file
# Writing place to file
# Writing fierceness to file
# Writing wake to file
# Writing warehouses to file
# Writing distrustful to file
# Writing flip to file
# Writing sow to file
# Writing subterraneousness to file
# Writing fearing to file
# Writing misfortune to file
# Writing nondescript to file
# Writing conversation to file
# Writing ego to file
# Writing escaped to file
# Writing reeved to file
# Writing amittai to file
# Writing fail to file
# Writing officer to file
# Writing tablecloth to file
# Writing mightier to file
# Writing devotee to file
# Writing faithfully to file
# Writing unchallenged to file
# Writing pascal to file
# Writing passion to file
# Writing waiving to file
# Writing recognition to file
# Writing measures to file
# Writing geological to file
# Writing winking to file
# Writing maketh to file
# Writing intertangled to file
# Writing tedious to file
# Writing hangman to file
# Writing men to file
# Writing rockaway to file
# Writing age to file
# Writing miscellaneous to file
# Writing sitting to file
# Writing inadequately to file
# Writing unpublished to file
# Writing mecca to file
# Writing snugly to file
# Writing cetology to file
# Writing cakes to file
# Writing averred to file
# Writing quoggy to file
# Writing trophies to file
# Writing markest to file
# Writing annawon to file
# Writing seat to file
# Writing give to file
# Writing shreds to file
# Writing coiling to file
# Writing ignite to file
# Writing attend to file
# Writing crying to file
# Writing whichever to file
# Writing indirectly to file
# Writing begat to file
# Writing isolate to file
# Writing extending to file
# Writing fuss to file
# Writing reddened to file
# Writing flailings to file
# Writing conquered to file
# Writing spells to file
# Writing sail to file
# Writing stagger to file
# Writing enjoins to file
# Writing approach to file
# Writing hour to file
# Writing equinoctial to file
# Writing bedside to file
# Writing landing to file
# Writing grasshopper to file
# Writing skip to file
# Writing traitors to file
# Writing carking to file
# Writing petticoat to file
# Writing covers to file
# Writing voice to file
# Writing wheat to file
# Writing ultimatum to file
# Writing holdest to file
# Writing unexaggerated to file
# Writing beset to file
# Writing kindred to file
# Writing havoc to file
# Writing acridness to file
# Writing befall to file
# Writing repeatedly to file
# Writing transcends to file
# Writing ketos to file
# Writing imbibing to file
# Writing dint to file
# Writing habitudes to file
# Writing dey to file
# Writing youth to file
# Writing involving to file
# Writing gleams to file
# Writing trowsers to file
# Writing prolongings to file
# Writing ignited to file
# Writing pippin to file
# Writing ain to file
# Writing scales to file
# Writing buttons to file
# Writing foretell to file
# Writing learn to file
# Writing feeder to file
# Writing odd to file
# Writing rich to file
# Writing suggestiveness to file
# Writing languages to file
# Writing zodiac to file
# Writing fifteen to file
# Writing splash to file
# Writing afford to file
# Writing procuring to file
# Writing because to file
# Writing adhesiveness to file
# Writing diligently to file
# Writing period to file
# Writing wages to file
# Writing snortings to file
# Writing efficient to file
# Writing paid to file
# Writing cheering to file
# Writing bout to file
# Writing mysterious to file
# Writing solitary to file
# Writing midship to file
# Writing canst to file
# Writing ticking to file
# Writing buttoned to file
# Writing ark to file
# Writing purporting to file
# Writing impute to file
# Writing widely to file
# Writing fat to file
# Writing eagerness to file
# Writing rinaldini to file
# Writing anxieties to file
# Writing mid to file
# Writing peppered to file
# Writing claim to file
# Writing earth to file
# Writing eternities to file
# Writing unsounded to file
# Writing readiness to file
# Writing providential to file
# Writing rolls to file
# Writing indomitableness to file
# Writing forming to file
# Writing thistles to file
# Writing ceasing to file
# Writing dyspeptic to file
# Writing haunts to file
# Writing comparing to file
# Writing perfect to file
# Writing grog to file
# Writing shinbone to file
# Writing richard to file
# Writing flouts to file
# Writing peculiar to file
# Writing vesture to file
# Writing ensue to file
# Writing repaired to file
# Writing moustache to file
# Writing london to file
# Writing cherrying to file
# Writing sentimentalist to file
# Writing hooks to file
# Writing bosky to file
# Writing hypothesis to file
# Writing subsiding to file
# Writing descended to file
# Writing sick to file
# Writing gloom to file
# Writing streamed to file
# Writing manage to file
# Writing toilette to file
# Writing free to file
# Writing curvicues to file
# Writing twice to file
# Writing stem to file
# Writing gash to file
# Writing voyage to file
# Writing lancet to file
# Writing bargain to file
# Writing gradual to file
# Writing its to file
# Writing sister to file
# Writing jeering to file
# Writing verbal to file
# Writing wilt to file
# Writing ambitious to file
# Writing crew to file
# Writing lifting to file
# Writing pumps to file
# Writing biscuit to file
# Writing presides to file
# Writing illuminating to file
# Writing murdering to file
# Writing cyphers to file
# Writing reclining to file
# Writing narrated to file
# Writing blocksburg to file
# Writing intuitions to file
# Writing irregularly to file
# Writing grimly to file
# Writing drags to file
# Writing hemisphere to file
# Writing merciless to file
# Writing horizons to file
# Writing finest to file
# Writing wind to file
# Writing supine to file
# Writing carcases to file
# Writing bang to file
# Writing upper to file
# Writing source to file
# Writing gritted to file
# Writing shark to file
# Writing estimated to file
# Writing peltry to file
# Writing darting to file
# Writing flee to file
# Writing exposing to file
# Writing slumbers to file
# Writing gable to file
# Writing mimicking to file
# Writing unwelcome to file
# Writing colours to file
# Writing lacks to file
# Writing idiotic to file
# Writing repelling to file
# Writing involved to file
# Writing pencil to file
# Writing screws to file
# Writing fagot to file
# Writing itch to file
# Writing rowing to file
# Writing whoel to file
# Writing thickets to file
# Writing sets to file
# Writing ruptured to file
# Writing doctor to file
# Writing quitting to file
# Writing kettles to file
# Writing influence to file
# Writing plaything to file
# Writing cenotaphs to file
# Writing bermudas to file
# Writing imperturbable to file
# Writing wings to file
# Writing bellies to file
# Writing spat to file
# Writing flash to file
# Writing enlarges to file
# Writing imposing to file
# Writing lure to file
# Writing padded to file
# Writing time to file
# Writing whelmed to file
# Writing pulsations to file
# Writing thundered to file
# Writing seething to file
# Writing brit to file
# Writing regulating to file
# Writing versions to file
# Writing concernments to file
# Writing emblematical to file
# Writing nor to file
# Writing lowermost to file
# Writing didst to file
# Writing replacing to file
# Writing undone to file
# Writing continuation to file
# Writing behalf to file
# Writing ger to file
# Writing teneriffe to file
# Writing sprained to file
# Writing behavior to file
# Writing hiss to file
# Writing menacing to file
# Writing prefer to file
# Writing disdained to file
# Writing investment to file
# Writing thinking to file
# Writing unflattering to file
# Writing integument to file
# Writing pox to file
# Writing stubbs to file
# Writing aldrovandus to file
# Writing text to file
# Writing vinegar to file
# Writing highness to file
# Writing seychelle to file
# Writing vertebrae to file
# Writing officially to file
# Writing pilau to file
# Writing hollow to file
# Writing wanted to file
# Writing trip to file
# Writing moorish to file
# Writing uncontaminated to file
# Writing morn to file
# Writing arctic to file
# Writing shrinked to file
# Writing speaker to file
# Writing woo to file
# Writing nill to file
# Writing bonapartes to file
# Writing her to file
# Writing ridden to file
# Writing sometimes to file
# Writing fool to file
# Writing lamps to file
# Writing professor to file
# Writing content to file
# Writing rosy to file
# Writing contrasted to file
# Writing circassian to file
# Writing forge to file
# Writing arched to file
# Writing conclusion to file
# Writing amelia to file
# Writing forbids to file
# Writing clubs to file
# Writing counted to file
# Writing cows to file
# Writing radiance to file
# Writing debel to file
# Writing staring to file
# Writing staggered to file
# Writing furnace to file
# Writing jumped to file
# Writing folly to file
# Writing thunderings to file
# Writing uncle to file
# Writing pictures to file
# Writing delusions to file
# Writing wallet to file
# Writing wildly to file
# Writing aunts to file
# Writing chargers to file
# Writing study to file
# Writing isinglass to file
# Writing sneaking to file
# Writing chapel to file
# Writing initiated to file
# Writing did to file
# Writing leather to file
# Writing visitations to file
# Writing naturalist to file
# Writing roaring to file
# Writing aggregated to file
# Writing pacific to file
# Writing dandies to file
# Writing william to file
# Writing stirred to file
# Writing frisky to file
# Writing music to file
# Writing periodically to file
# Writing scratch to file
# Writing tranced to file
# Writing persist to file
# Writing cooking to file
# Writing sheaved to file
# Writing gemini to file
# Writing proportions to file
# Writing wellington to file
# Writing scarcely to file
# Writing persian to file
# Writing pace to file
# Writing flaw to file
# Writing countersinkers to file
# Writing another to file
# Writing mistakes to file
# Writing this to file
# Writing cetacea to file
# Writing feat to file
# Writing mowers to file
# Writing centralization to file
# Writing ordinaire to file
# Writing orphan to file
# Writing rust to file
# Writing cat to file
# Writing better to file
# Writing vacuum to file
# Writing tags to file
# Writing cargoes to file
# Writing erroneous to file
# Writing burying to file
# Writing heron to file
# Writing subsequent to file
# Writing hilarity to file
# Writing said to file
# Writing fling to file
# Writing tenth to file
# Writing athirst to file
# Writing interpreting to file
# Writing lording to file
# Writing lamp to file
# Writing throned to file
# Writing manifesto to file
# Writing pearl to file
# Writing match to file
# Writing wring to file
# Writing hove to file
# Writing exclamations to file
# Writing feel to file
# Writing hazards to file
# Writing converted to file
# Writing touching to file
# Writing shortest to file
# Writing woman to file
# Writing band to file
# Writing instinctively to file
# Writing finally to file
# Writing towing to file
# Writing dismemberer to file
# Writing plunged to file
# Writing hereabouts to file
# Writing blasphemy to file
# Writing draught to file
# Writing shavings to file
# Writing tingled to file
# Writing fedallah to file
# Writing tides to file
# Writing flexion to file
# Writing outlandish to file
# Writing purposes to file
# Writing cruelty to file
# Writing many to file
# Writing flakes to file
# Writing high to file
# Writing nuts to file
# Writing reach to file
# Writing bowels to file
# Writing equivalent to file
# Writing prudent to file
# Writing crape to file
# Writing cutter to file
# Writing communities to file
# Writing near to file
# Writing icebound to file
# Writing career to file
# Writing verbatim to file
# Writing escaping to file
# Writing foolish to file
# Writing edifices to file
# Writing learning to file
# Writing incidental to file
# Writing broke to file
# Writing twig to file
# Writing acquiescence to file
# Writing puritans to file
# Writing agents to file
# Writing ministry to file
# Writing sharper to file
# Writing rights to file
# Writing murderers to file
# Writing jeweller to file
# Writing crushing to file
# Writing hissed to file
# Writing support to file
# Writing ascertained to file
# Writing adopted to file
# Writing moses to file
# Writing fork to file
# Writing how to file
# Writing elks to file
# Writing office to file
# Writing ten to file
# Writing dad to file
# Writing ork to file
# Writing chimneys to file
# Writing investigator to file
# Writing undoubtedly to file
# Writing barges to file
# Writing aleak to file
# Writing wildness to file
# Writing remarking to file
# Writing seldom to file
# Writing terrible to file
# Writing publisher to file
# Writing senses to file
# Writing keel to file
# Writing siding to file
# Writing surveyor to file
# Writing hanging to file
# Writing appellative to file
# Writing nantucketers to file
# Writing becalmed to file
# Writing junk to file
# Writing disappearance to file
# Writing phantom to file
# Writing wolf to file
# Writing tapered to file
# Writing quadrant to file
# Writing whittled to file
# Writing circumventing to file
# Writing radiates to file
# Writing surpassingly to file
# Writing ubiquitous to file
# Writing contenting to file
# Writing bloody to file
# Writing unmomentous to file
# Writing objections to file
# Writing waif to file
# Writing spiral to file
# Writing placidity to file
# Writing jordan to file
# Writing crowd to file
# Writing monks to file
# Writing gathering to file
# Writing kine to file
# Writing pine to file
# Writing what to file
# Writing clime to file
# Writing eyest to file
# Writing dim to file
# Writing unscrupulous to file
# Writing hieroglyphical to file
# Writing likes to file
# Writing series to file
# Writing olfactories to file
# Writing throbs to file
# Writing tropics to file
# Writing maccabees to file
# Writing unhinted to file
# Writing jollily to file
# Writing embracing to file
# Writing vision to file
# Writing triangles to file
# Writing respires to file
# Writing gloriously to file
# Writing poncho to file
# Writing spencer to file
# Writing excellently to file
# Writing flood to file
# Writing dashed to file
# Writing numbered to file
# Writing titans to file
# Writing unobservant to file
# Writing restrained to file
# Writing loose to file
# Writing fainter to file
# Writing blessing to file
# Writing weasel to file
# Writing related to file
# Writing outburst to file
# Writing pronouncing to file
# Writing neighbors to file
# Writing tho to file
# Writing hasn to file
# Writing ten to file
# Writing browsing to file
# Writing bountiful to file
# Writing goin to file
# Writing amounted to file
# Writing lookest to file
# Writing huge to file
# Writing mobbing to file
# Writing gun to file
# Writing haggardly to file
# Writing tulips to file
# Writing arose to file
# Writing stateliest to file
# Writing lived to file
# Writing brace to file
# Writing kinsmen to file
# Writing building to file
# Writing rowed to file
# Writing killers to file
# Writing following to file
# Writing friends to file
# Writing knight to file
# Writing rebels to file
# Writing chiefs to file
# Writing courageousness to file
# Writing insulting to file
# Writing swum to file
# Writing shop to file
# Writing assails to file
# Writing forewarned to file
# Writing veal to file
# Writing recovered to file
# Writing alarmed to file
# Writing brotherhood to file
# Writing fevers to file
# Writing merchant to file
# Writing record to file
# Writing embarks to file
# Writing positively to file
# Writing unexhilarated to file
# Writing damocles to file
# Writing need to file
# Writing associated to file
# Writing after to file
# Writing gazettes to file
# Writing apoplectic to file
# Writing japanese to file
# Writing fundamental to file
# Writing shoe to file
# Writing captured to file
# Writing tepid to file
# Writing admits to file
# Writing wonders to file
# Writing powers to file
# Writing magical to file
# Writing whimsiness to file
# Writing conflagration to file
# Writing from to file
# Writing circumstance to file
# Writing flounders to file
# Writing furnished to file
# Writing wedded to file
# Writing flanked to file
# Writing scornest to file
# Writing sow to file
# Writing socket to file
# Writing ocean to file
# Writing overpowered to file
# Writing after to file
# Writing beelzebub to file
# Writing thrills to file
# Writing plains to file
# Writing logged to file
# Writing bonnet to file
# Writing unpanelled to file
# Writing tish to file
# Writing into to file
# Writing could to file
# Writing mapple to file
# Writing scornfully to file
# Writing furls to file
# Writing shivers to file
# Writing masts to file
# Writing netted to file
# Writing wrinkled to file
# Writing exhausted to file
# Writing showed to file
# Writing desperadoes to file
# Writing sentinels to file
# Writing bait to file
# Writing manikin to file
# Writing damn to file
# Writing chapters to file
# Writing bourbons to file
# Writing platonian to file
# Writing nature to file
# Writing waded to file
# Writing grizzled to file
# Writing death to file
# Writing utter to file
# Writing wasn to file
# Writing stumps to file
# Writing informed to file
# Writing backwoods to file
# Writing falsified to file
# Writing wigwam to file
# Writing instant to file
# Writing similes to file
# Writing sea to file
# Writing flume to file
# Writing ponderous to file
# Writing upliftings to file
# Writing chat to file
# Writing premium to file
# Writing quivered to file
# Writing hoods to file
# Writing unstaggering to file
# Writing tortoise to file
# Writing skrimshandering to file
# Writing madman to file
# Writing entailed to file
# Writing compounded to file
# Writing humble to file
# Writing shadowed to file
# Writing freebooters to file
# Writing dumb to file
# Writing stare to file
# Writing towers to file
# Writing unlike to file
# Writing massacre to file
# Writing slopes to file
# Writing glimmer to file
# Writing unattended to file
# Writing larceny to file
# Writing tower to file
# Writing smuggled to file
# Writing passionate to file
# Writing disciples to file
# Writing comest to file
# Writing perhaps to file
# Writing physiognomically to file
# Writing golconda to file
# Writing backbone to file
# Writing gets to file
# Writing foul to file
# Writing witnesses to file
# Writing originated to file
# Writing malefactors to file
# Writing authenticated to file
# Writing senate to file
# Writing mathematically to file
# Writing prediction to file
# Writing weaker to file
# Writing writhing to file
# Writing indefinitely to file
# Writing divine to file
# Writing nautilus to file
# Writing landsmen to file
# Writing commanders to file
# Writing sachem to file
# Writing accosted to file
# Writing heart to file
# Writing prior to file
# Writing lustrous to file
# Writing uneasy to file
# Writing tower to file
# Writing opportunities to file
# Writing intimacy to file
# Writing crockery to file
# Writing exclamation to file
# Writing marking to file
# Writing swiftly to file
# Writing habituation to file
# Writing throughout to file
# Writing replaced to file
# Writing smiled to file
# Writing endued to file
# Writing seeva to file
# Writing mutineer to file
# Writing concussions to file
# Writing cape to file
# Writing gorge to file
# Writing adieux to file
# Writing insider to file
# Writing giraffe to file
# Writing new to file
# Writing objection to file
# Writing burtons to file
# Writing interpreter to file
# Writing punchbowl to file
# Writing waving to file
# Writing worried to file
# Writing increased to file
# Writing toed to file
# Writing fronting to file
# Writing freckles to file
# Writing islands to file
# Writing trouble to file
# Writing turkey to file
# Writing modifies to file
# Writing oaths to file
# Writing for to file
# Writing ferdinando to file
# Writing rounds to file
# Writing better to file
# Writing professions to file
# Writing ruminated to file
# Writing graved to file
# Writing antelope to file
# Writing odorless to file
# Writing cathedral to file
# Writing impulse to file
# Writing central to file
# Writing skewer to file
# Writing announced to file
# Writing sphinx to file
# Writing shame to file
# Writing cinnamon to file
# Writing vehemently to file
# Writing invaded to file
# Writing rolled to file
# Writing stick to file
# Writing withdrawn to file
# Writing twice to file
# Writing brings to file
# Writing inspire to file
# Writing managers to file
# Writing brightness to file
# Writing indirect to file
# Writing confederate to file
# Writing democratic to file
# Writing saint to file
# Writing poring to file
# Writing calabash to file
# Writing plainest to file
# Writing destruction to file
# Writing eternities to file
# Writing tomorrow to file
# Writing character to file
# Writing classification to file
# Writing huggins to file
# Writing obtains to file
# Writing wish to file
# Writing divisions to file
# Writing stall to file
# Writing engendered to file
# Writing places to file
# Writing blunder to file
# Writing raised to file
# Writing brimming to file
# Writing prating to file
# Writing fishing to file
# Writing odorous to file
# Writing octavo to file
# Writing accordingly to file
# Writing repair to file
# Writing schooners to file
# Writing lord to file
# Writing vivifying to file
# Writing coerced to file
# Writing say to file
# Writing dilated to file
# Writing bess to file
# Writing cloud to file
# Writing affords to file
# Writing authorized to file
# Writing capstan to file
# Writing casualties to file
# Writing hurrah to file
# Writing esquimaux to file
# Writing voyage to file
# Writing gliding to file
# Writing lunges to file
# Writing fierce to file
# Writing slip to file
# Writing twelvemonth to file
# Writing malicious to file
# Writing otherwise to file
# Writing consult to file
# Writing suggestions to file
# Writing forged to file
# Writing appetites to file
# Writing persia to file
# Writing market to file
# Writing tarquin to file
# Writing carson to file
# Writing pall to file
# Writing cleveland to file
# Writing breeding to file
# Writing millions to file
# Writing paintings to file
# Writing continuous to file
# Writing warning to file
# Writing lid to file
# Writing continents to file
# Writing midmost to file
# Writing pennons to file
# Writing greyhound to file
# Writing hermaphroditical to file
# Writing carpenters to file
# Writing aldrovandi to file
# Writing keeper to file
# Writing hogs to file
# Writing hamper to file
# Writing silvery to file
# Writing ornamental to file
# Writing stagnant to file
# Writing secrecy to file
# Writing radical to file
# Writing acquainted to file
# Writing fountain to file
# Writing bore to file
# Writing wights to file
# Writing confinement to file
# Writing emprise to file
# Writing gorgeous to file
# Writing bitterest to file
# Writing sailed to file
# Writing meal to file
# Writing backs to file
# Writing marling to file
# Writing coronation to file
# Writing taken to file
# Writing har to file
# Writing conspired to file
# Writing hardly to file
# Writing merely to file
# Writing blanket to file
# Writing header to file
# Writing overgrowth to file
# Writing forge to file
# Writing halyards to file
# Writing firmest to file
# Writing alive to file
# Writing less to file
# Writing conspicuous to file
# Writing torsoes to file
# Writing overdone to file
# Writing benevolently to file
# Writing hay to file
# Writing exhibit to file
# Writing superlatively to file
# Writing scalp to file
# Writing resting to file
# Writing prophesy to file
# Writing skipper to file
# Writing herded to file
# Writing expected to file
# Writing wheelbarrow to file
# Writing triumph to file
# Writing greeks to file
# Writing mild to file
# Writing curving to file
# Writing enrolled to file
# Writing booting to file
# Writing lawless to file
# Writing dimmed to file
# Writing reduced to file
# Writing promontory to file
# Writing downward to file
# Writing baleen to file
# Writing reference to file
# Writing philosophies to file
# Writing impulsively to file
# Writing fastening to file
# Writing surcoat to file
# Writing feverishly to file
# Writing down to file
# Writing uncomfortable to file
# Writing yellow to file
# Writing withdraws to file
# Writing rig to file
# Writing commentator to file
# Writing fadeless to file
# Writing skulled to file
# Writing signs to file
# Writing cattegat to file
# Writing chamois to file
# Writing elephanta to file
# Writing bows to file
# Writing fourth to file
# Writing endless to file
# Writing invoked to file
# Writing admonitions to file
# Writing nimbly to file
# Writing xerxes to file
# Writing quickening to file
# Writing babe to file
# Writing inquiries to file
# Writing castor to file
# Writing silver to file
# Writing america to file
# Writing exaggerating to file
# Writing matse to file
# Writing solemn to file
# Writing our to file
# Writing wilful to file
# Writing archangels to file
# Writing lotus to file
# Writing real to file
# Writing mostly to file
# Writing emblazoned to file
# Writing enter to file
# Writing distinction to file
# Writing helping to file
# Writing goa to file
# Writing necessity to file
# Writing breathes to file
# Writing continued to file
# ...
# Writing scoured to file
# Writing herr to file
# Writing longed to file
# Writing promenade to file
# Writing semicircular to file
# Writing borneo to file
# Writing harder to file
# Writing architect to file
# Writing caryatid to file
# Writing famed to file
# Writing bachelor to file
# Writing tens to file
# Writing palms to file
# Writing realize to file
# Writing halted to file
# Writing investigations to file
# Writing swooped to file
# Writing battering to file
# Writing whaled to file
# Writing ahaz to file
# Writing paracelsan to file
# Writing dampness to file
# Writing clay to file
# Writing something to file
# Writing sweeter to file
# Writing sleet to file
# Writing pull to file
# Writing tranquilly to file
# Writing placing to file
# Writing lifted to file
# Writing cash to file
# Writing foamy to file
# Writing you to file
# Writing preserving to file
# Writing nonplussed to file
# Writing scraped to file
# Writing gettee to file
# Writing tend to file
# Writing puffing to file
# Writing cutlet to file
# Writing maelstrom to file
# Writing loosed to file
# Writing unfearing to file
# Writing gas to file
# Writing dodge to file
# Writing extras to file
# Writing winces to file
# Writing imparts to file
# Writing eluded to file
# Writing tattooing to file
# Writing programme to file
# Writing monarch to file
# Writing completed to file
# Writing dispersed to file
# Writing rowlocks to file
# Writing desisted to file
# Writing wondering to file
# Writing prophecies to file
# Writing lightness to file
# Writing obtained to file
# Writing primitively to file
# Writing fruition to file
# Writing shiftings to file
# Writing wallowing to file
# Writing declared to file
# Writing mingling to file
# Writing intermission to file
# Writing unexpected to file
# Writing siamese to file
# Writing griefs to file
# Writing arisen to file
# Writing loweringly to file
# Writing thrusted to file
# Writing carried to file
# Writing butterfly to file
# Writing tester to file
# Writing acquiesce to file
# Writing familiar to file
# Writing driving to file
# Writing transported to file
# Writing dissembling to file
# Writing motley to file
# Writing circles to file
# Writing fuego to file
# Writing bailer to file
# Writing undress to file
# Writing waller to file
# Writing shame to file
# Writing gras to file
# Writing outbranching to file
# Writing groves to file
# Writing tennessee to file
# Writing aware to file
# Writing rogues to file
# Writing dramatically to file
# Writing manhattoes to file
# Writing grassy to file
# Writing flames to file
# Writing clanking to file
# Writing term to file
# Writing empire to file
# Writing unfathered to file
# Writing watchmakers to file
# Writing baptised to file
# Writing harmony to file
# Writing maddening to file
# Writing allusion to file
# Writing architects to file
# Writing welding to file
# Writing establish to file
# Writing gross to file
# Writing lane to file
# Writing craters to file
# Writing anything to file
# Writing cleanliest to file
# Writing angelo to file
# Writing lunacy to file
# Writing gasps to file
# Writing discreetly to file
# Writing shipwreck to file
# Writing ports to file
# Writing section to file
# Writing over to file
# Writing lacquered to file
# Writing hindoos to file
# Writing midships to file
# Writing tick to file
# Writing concern to file
# Writing straps to file
# Writing lose to file
# Writing dance to file
# Writing lake to file
# Writing abode to file
# Writing slices to file
# Writing brush to file
# Writing nantucket to file
# Writing mates to file
# Writing middling to file
# Writing accumulated to file
# Writing echo to file
# Writing delight to file
# Writing unexpectedly to file
# Writing lapse to file
# Writing recalled to file
# Writing coincidings to file
# Writing swamp to file
# Writing sap to file
# Writing line to file
# Writing improbable to file
# Writing letter to file
# Writing offspring to file
# Writing intact to file
# Writing dreadful to file
# Writing duelled to file
# Writing ferrule to file
# Writing cast to file
# Writing unappeasable to file
# Writing suspicions to file
# Writing parcel to file
# Writing pirate to file
# Writing archipelagoes to file
# Writing directed to file
# Writing alleged to file
# Writing clubbed to file
# Writing affinities to file
# Writing aware to file
# Writing energy to file
# Writing amazement to file
# Writing unappalled to file
# Writing died to file
# Writing canonized to file
# Writing inducing to file
# Writing stockinged to file
# Writing frighten to file
# Writing prudently to file
# Writing nets to file
# Writing exegetist to file
# Writing drinks to file
# Writing quietest to file
# Writing graduates to file
# Writing lacings to file
# Writing rapping to file
# Writing which to file
# Writing emperor to file
# Writing characterizing to file
# Writing curdling to file
# Writing book to file
# Writing like to file
# Writing simplicity to file
# Writing entreaties to file
# Writing spite to file
# Writing swordsman to file
# Writing ungentlemanly to file
# Writing philosophy to file
# Writing bristles to file
# Writing patris to file
# Writing sleeves to file
# Writing corlears to file
# Writing ifs to file
# Writing painfulness to file
# Writing profile to file
# Writing cheever to file
# Writing clotting to file
# Writing ideal to file
# Writing mantle to file
# Writing halibut to file
# Writing beloved to file
# Writing oars to file
# Writing comstock to file
# Writing hand to file
# Writing disreputable to file
# Writing shut to file
# Writing murdered to file
# Writing unwarrantable to file
# Writing bite to file
# Writing doing to file
# Writing curds to file
# Writing cleat to file
# Writing caution to file
# Writing beware to file
# Writing syracuse to file
# Writing astrological to file
# Writing prophesied to file
# Writing cooper to file
# Writing divined to file
# Writing crabs to file
# Writing dines to file
# Writing care to file
# Writing raal to file
# Writing quoted to file
# Writing scuttle to file
# Writing bibles to file
# Writing argosy to file
# Writing credit to file
# Writing tablet to file
# Writing served to file
# Writing methodic to file
# Writing laughing to file
# Writing precious to file
# Writing brutes to file
# Writing threatened to file
# Writing appear to file
# Writing most to file
# Writing quietude to file
# Writing deliver to file
# Writing afternoon to file
# Writing choke to file
# Writing sharing to file
# Writing remark to file
# Writing betrayed to file
# Writing feigned to file
# Writing see to file
# Writing jonas to file
# Writing thus to file
# Writing these to file
# Writing evanescent to file
# Writing feelest to file
# Writing proportioned to file
# Writing faculties to file
# Writing simeon to file
# Writing portentousness to file
# Writing lascars to file
# Writing phrensy to file
# Writing wounding to file
# Writing montaigne to file
# Writing outfit to file
# Writing boy to file
# Writing firmly to file
# Writing cowper to file
# Writing haters to file
# Writing details to file
# Writing indication to file
# Writing monumental to file
# Writing beheld to file
# Writing bench to file
# Writing row to file
# Writing imperceptibly to file
# Writing invariability to file
# Writing gather to file
# Writing doer to file
# Writing gizzard to file
# Writing cobweb to file
# Writing inordinate to file
# Writing chimed to file
# Writing laugh to file
# Writing swing to file
# Writing potluck to file
# Writing shocked to file
# Writing studying to file
# Writing sanctum to file
# Writing tantalizing to file
# Writing bottle to file
# Writing pitches to file
# Writing darkens to file
# Writing marshals to file
# Writing ample to file
# Writing waterward to file
# Writing insular to file
# Writing tusked to file
# Writing supply to file
# Writing paine to file
# Writing abandonedly to file
# Writing conquest to file
# Writing unconditionally to file
# Writing lightnings to file
# Writing forts to file
# Writing squeezing to file
# Writing step to file
# Writing balaene to file
# Writing workmanlike to file
# Writing dismay to file
# Writing vowed to file
# Writing tastefully to file
# Writing generous to file
# Writing flake to file
# Writing because to file
# Writing frenchman to file
# Writing milk to file
# Writing asleep to file
# Writing luxurious to file
# Writing towering to file
# Writing officered to file
# Writing noted to file
# Writing sharpen to file
# Writing project to file
# Writing with to file
# Writing heedfulness to file
# Writing watches to file
# Writing town to file
# Writing tumults to file
# Writing easy to file
# Writing comfort to file
# Writing grapes to file
# Writing poor to file
# Writing ventilated to file
# Writing personal to file
# Writing tranquil to file
# Writing circumambulate to file
# Writing helmsman to file
# Writing boastful to file
# Writing gentle to file
# Writing keepers to file
# Writing rokovoko to file
# Writing leading to file
# Writing elastic to file
# Writing sprinkling to file
# Writing unborrowed to file
# Writing bubblingly to file
# Writing reg to file
# Writing buoyantly to file
# Writing improvement to file
# Writing mirror to file
# Writing ween to file
# Writing arts to file
# Writing forgets to file
# Writing superfluous to file
# Writing oblige to file
# Writing adolescence to file
# Writing pluck to file
# Writing folios to file
# Writing turns to file
# Writing unconscious to file
# Writing comes to file
# Writing german to file
# Writing observance to file
# Writing blackish to file
# Writing triumphal to file
# Writing keener to file
# Writing inhabitants to file
# Writing foreign to file
# Writing recoil to file
# Writing gazing to file
# Writing proved to file
# Writing perishable to file
# Writing scene to file
# Writing profoundest to file
# Writing shadings to file
# Writing steeped to file
# Writing empty to file
# Writing vapoury to file
# Writing sideways to file
# Writing arnold to file
# Writing insinuates to file
# Writing thrice to file
# Writing prayed to file
# Writing uprising to file
# Writing massacre to file
# Writing pervading to file
# Writing exert to file
# Writing boldly to file
# Writing world to file
# Writing neat to file
# Writing pursued to file
# Writing backwards to file
# Writing waved to file
# Writing gravity to file
# Writing knobs to file
# Writing pill to file
# Writing bunched to file
# Writing slink to file
# Writing heroes to file
# Writing preliminaries to file
# Writing ferocity to file
# Writing bawl to file
# Writing snatching to file
# Writing laceration to file
# Writing assisting to file
# Writing occult to file
# Writing pillar to file
# Writing relented to file
# Writing got to file
# Writing chrysalis to file
# Writing bundling to file
# Writing enlist to file
# Writing she to file
# Writing insensible to file
# Writing didn to file
# Writing shooting to file
# Writing eckerman to file
# Writing precautionary to file
# Writing dusk to file
# Writing additional to file
# Writing sheeted to file
# Writing marge to file
# Writing throat to file
# Writing plight to file
# Writing jeeringly to file
# Writing persisting to file
# Writing australian to file
# Writing work to file
# Writing jonathan to file
# Writing thee to file
# Writing globules to file
# Writing serfs to file
# Writing fellow to file
# Writing heathen to file
# Writing pleasure to file
# Writing whether to file
# Writing impersonal to file
# Writing considerably to file
# Writing popularize to file
# Writing parts to file
# Writing marine to file
# Writing cinders to file
# Writing piratical to file
# Writing you to file
# Writing tornado to file
# Writing pan to file
# Writing startlingly to file
# Writing analogies to file
# Writing drawlingly to file
# Writing ruggedness to file
# Writing rate to file
# Writing burkes to file
# Writing gaining to file
# Writing patched to file
# Writing confined to file
# Writing delights to file
# Writing gaudiest to file
# Writing fresher to file
# Writing uncommonly to file
# Writing minutes to file
# Writing wilted to file
# Writing told to file
# Writing large to file
# Writing goat to file
# Writing lancers to file
# Writing palmy to file
# Writing historians to file
# Writing falling to file
# Writing busily to file
# Writing satisfy to file
# Writing navy to file
# Writing slid to file
# Writing ruling to file
# Writing southern to file
# Writing shoals to file
# Writing clutch to file
# Writing nibbling to file
# Writing earnestness to file
# Writing drizzly to file
# Writing sheltered to file
# Writing broadly to file
# Writing entertaining to file
# Writing harpooning to file
# Writing sal to file
# Writing somnambulistic to file
# Writing parallel to file
# Writing opposing to file
# Writing elephants to file
# Writing pantomime to file
# Writing portraits to file
# Writing superiority to file
# Writing file to file
# Writing rabid to file
# Writing bursting to file
# Writing traditions to file
# Writing decanting to file
# Writing ray to file
# Writing sailing to file
# Writing guinea to file
# Writing humpback to file
# Writing incompetence to file
# Writing account to file
# Writing counterpane to file
# Writing mackerel to file
# Writing maker to file
# Writing whatever to file
# Writing influences to file
# Writing whisker to file
# Writing mutual to file
# Writing spouters to file
# Writing class to file
# Writing plant to file
# Writing succeed to file
# Writing cherries to file
# Writing struggles to file
# Writing vineyards to file
# Writing whim to file
# Writing meeting to file
# Writing cold to file
# Writing indispensableness to file
# Writing deserving to file
# Writing vividness to file
# Writing hallowed to file
# Writing face to file
# Writing lighter to file
# Writing unspeckled to file
# Writing more to file
# Writing quickest to file
# Writing indefatigable to file
# Writing emblazoning to file
# Writing cents to file
# Writing serpentine to file
# Writing unfailing to file
# Writing landed to file
# Writing sunny to file
# Writing crooked to file
# Writing smithies to file
# Writing tails to file
# Writing spangling to file
# Writing held to file
# Writing test to file
# Writing passions to file
# Writing knowest to file
# Writing mine to file
# Writing meddling to file
# Writing conversations to file
# Writing devote to file
# Writing pinch to file
# Writing gone to file
# Writing grand to file
# Writing amplify to file
# Writing mammiferous to file
# Writing behind to file
# Writing antemosaic to file
# Writing cables to file
# Writing bethink to file
# Writing depressed to file
# Writing mapped to file
# Writing subalterns to file
# Writing singular to file
# Writing diademed to file
# Writing agassiz to file
# Writing deposited to file
# Writing whales to file
# Writing records to file
# Writing samson to file
# Writing beehive to file
# Writing hit to file
# Writing hazard to file
# Writing comprises to file
# Writing crawled to file
# Writing plaited to file
# Writing scrubbed to file
# Writing grave to file
# Writing shingled to file
# Writing dangling to file
# Writing spices to file
# Writing fore to file
# Writing chaplain to file
# Writing halving to file
# Writing controverted to file
# Writing dwells to file
# Writing pony to file
# Writing electricity to file
# Writing vagrant to file
# Writing swore to file
# Writing unprincipled to file
# Writing lees to file
# Writing electric to file
# Writing vero to file
# Writing flail to file
# Writing eastern to file
# Writing chicha to file
# Writing rivallingly to file
# Writing abandoned to file
# Writing slabs to file
# Writing historical to file
# Writing date to file
# Writing ambiguous to file
# Writing madly to file
# Writing sore to file
# Writing telling to file
# Writing construct to file
# Writing foremast to file
# Writing differs to file
# Writing cant to file
# Writing supernaturalness to file
# Writing encamp to file
# Writing sorrows to file
# Writing black to file
# Writing porpoise to file
# Writing exception to file
# Writing brokenly to file
# Writing cords to file
# Writing revolvingly to file
# Writing unwinding to file
# Writing comforters to file
# Writing probabilities to file
# Writing protuberance to file
# Writing pulpy to file
# Writing attack to file
# Writing maples to file
# Writing cupola to file
# Writing disentangling to file
# Writing stride to file
# Writing peered to file
# Writing predecessors to file
# Writing stroll to file
# Writing counsels to file
# Writing quilt to file
# Writing husband to file
# Writing buffalo to file
# Writing propose to file
# Writing bask to file
# Writing champollion to file
# Writing somewhere to file
# Writing folder to file
# Writing spread to file
# Writing light to file
# Writing loudly to file
# Writing land to file
# Writing spaciousness to file
# Writing surrounding to file
# Writing infecting to file
# Writing horse to file
# Writing king to file
# Writing torn to file
# Writing densely to file
# Writing homes to file
# Writing race to file
# Writing sights to file
# Writing eaves to file
# Writing gambol to file
# Writing incompetency to file
# Writing suppressed to file
# Dataset preparation successful.. Check ./data
